# %% [markdown]
# <a href="https://colab.research.google.com/github/arungeethanbk/AL-Project---corizo/blob/al/cardiovascular_disease_prediction_minor_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('cardio_train.csv', delimiter=';')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.sample(15)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 16231  23187  23244       1     153    81.0    135     80            2     2
# 48571  69354  22045       1     160    60.0    120     80            1     1
# 55235  78794  21205       2     168    66.0    120     80            3     3
# 40543  57937  19112       1     160    78.0    120     80            1     1
# 1721    2435  16266       1     162    72.0    145     90            3     3
# 19013  27148  19911       1     162    61.0    140     80            2     2
# 28263  40399  17540       1     155    61.0    110     70            1     1
# 24370  34818  21828       1     160    62.0    120     90            1     1
# 8454   12065  19385       1     170    72.0    120     80            1     1
# 54367  77547  20392       1     156    66.0    130     80            1     1
# 10129  14439  15320       1     156    74.0    130     80            3     1
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df['cholesterol'].unique()
# Out:
# array([1, 3, 2])

# %%
df['cardio'].nunique()
# Out:
# 2

# %%
df.nunique()
# Out:
# id             70000
# age             8076
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64

# %%
df.drop('id', axis=1, inplace=True)

# %%
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
df['age']=(df['age']/365).round().astype(int)

# %%
df
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       2     168    62.0    110     80            1     1      0
# 1       55       1     156    85.0    140     90            3     1      0
# 2       52       1     165    64.0    130     70            3     1      0
# 3       48       2     169    82.0    150    100            1     1      0
# 4       48       1     156    56.0    100     60            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995   53       2     168    76.0    120     80            1     1      1
# 69996   62       1     158   126.0    140     90            2     2      0
# 69997   52       2     183   105.0    180     90            3     1      0
# 69998   61       1     163    72.0    135     80            1     2      0
# 69999   56       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# ...

# %%
df.duplicated().sum()
# Out:
# 3816

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df['age'].nunique()
# Out:
# 28

# %%
df['cholesterol'].value_counts()
# Out:
# cholesterol
# 1    48652
# 2     9518
# 3     8014
# Name: count, dtype: int64

# %%
df['gluc'].value_counts()
# Out:
# gluc
# 1    55708
# 3     5287
# 2     5189
# Name: count, dtype: int64

# %%
df['bmi']=df['weight']/(df['height']/100)**2

# %%
df.drop(['weight', 'height'], axis=1, inplace = True)

# %%
plt.figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
df.plot(kind='box')
plt.axis(xmin=0, xmax=14, ymin=1, ymax=200
         )
# Out:
# (0.0, 14.0, 1.0, 200.0)

# %%
df.corr()['cardio'].abs().sort_values(ascending=False)
# Out:
# cardio         1.000000
# age            0.234270
# cholesterol    0.213036
# bmi            0.157878
# gluc           0.080470
# ap_lo          0.064759
# ap_hi          0.053770
# active         0.027137
# smoke          0.023715
# alco           0.014259
# gender         0.001365
# Name: cardio, dtype: float64

# %%
correlation = df.select_dtypes('number').corr()

# %%
correlation
# Out:
#                   age    gender     ap_hi     ap_lo  cholesterol      gluc  \
# age          1.000000 -0.023792  0.020675  0.017589     0.156019  0.098916
# gender      -0.023792  1.000000  0.005159  0.014065    -0.044587 -0.026668
# ap_hi        0.020675  0.005159  1.000000  0.015771     0.022368  0.010762
# ap_lo        0.017589  0.014065  0.015771  1.000000     0.021686  0.009023
# cholesterol  0.156019 -0.044587  0.022368  0.021686     1.000000  0.443462
# gluc         0.098916 -0.026668  0.010762  0.009023     0.443462  1.000000
# smoke       -0.050144  0.340583 -0.001831  0.003731     0.002487 -0.010642
# alco        -0.031596  0.170933  0.000674  0.009437     0.029740  0.006645
# active      -0.009399  0.009320  0.000835  0.006278     0.019443  0.000582
# cardio       0.234270  0.001365  0.053770  0.064759     0.213036  0.080470
# bmi          0.084578 -0.105430  0.023604  0.033447     0.136914  0.094525
#
#                 smoke      alco    active    cardio       bmi
# ...

# %%
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(x='gender',y='cardio', data=df)
# Out:
# <Axes: xlabel='gender', ylabel='cardio'>

# %%
sns.countplot(x='gender', hue='cardio', data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
x =df.drop(['cardio'], axis=1)

x
# Out:
#        age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0       50       2    110     80            1     1      0     0       1
# 1       55       1    140     90            3     1      0     0       1
# 2       52       1    130     70            3     1      0     0       0
# 3       48       2    150    100            1     1      0     0       1
# 4       48       1    100     60            1     1      0     0       0
# ...    ...     ...    ...    ...          ...   ...    ...   ...     ...
# 69995   53       2    120     80            1     1      1     0       1
# 69996   62       1    140     90            2     2      0     0       1
# 69997   52       2    180     90            3     1      0     1       0
# 69998   61       1    135     80            1     2      0     0       0
# 69999   56       1    120     80            2     1      0     0       1
#
#              bmi
# 0      21.967120
# 1      34.927679
# 2      23.507805
# 3      28.710479
# ...

# %%
y=df['cardio']
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 66184, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # Linear Regresssion

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
lreg = LinearRegression()
lreg.fit(x_train, y_train)
y_pred=lreg.predict(x_test)
y_pred

# %%
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R-score:', r2)
# Out:
# Mean Squared Error: 0.22293870080978478
# R-score: 0.10810661639840691

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
Y_pred = logreg.predict(x_test)
accuracy = accuracy_score(y_test, Y_pred)
precision = precision_score(y_test, Y_pred)
recall = recall_score(y_test, Y_pred)
f1 = f1_score(y_test, Y_pred)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 score:', f1)
# Out:
# Accuracy: 0.7200271964946741
# Precision: 0.7295019157088123
# Recall: 0.7103417400388001
# F1 score: 0.7197943444730077
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
sns.heatmap(confusion_matrix(y_test, Y_pred), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
d_pred = dtc.predict(x_test)
print(accuracy_score(y_test, d_pred))
print(confusion_matrix(y_test, d_pred))
# Out:
# 0.6212888116642744
# [[4022 2514]
#  [2499 4202]]

# %%
sns.heatmap(confusion_matrix(y_test, d_pred), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
r_pred = rfc.predict(x_test)
print(accuracy_score(y_test, r_pred))
print(confusion_matrix(y_test, r_pred))
# Out:
# 0.6745486137342298
# [[4271 2265]
#  [2043 4658]]

# %%
sns.heatmap(confusion_matrix(y_test, r_pred), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
k_pred = knn.predict(x_test)
print(accuracy_score(y_test, k_pred))
print(confusion_matrix(y_test, k_pred))
# Out:
# 0.6966079927476014
# [[4607 1929]
#  [2087 4614]]

# %%
sns.heatmap(confusion_matrix(y_test, k_pred), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [100, 200, 300], 'max_depth': [None, 10, 20], 'min_samples_split': [2, 5, 10]}
grid_search = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=5)
grid_search.fit(x_train, y_train)
bestparams = grid_search.best_params_
bestscore = grid_search.best_score_
print(bestparams)
print(bestscore)
# Out:
# {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 300}
# 0.7309575020882841

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
g_pred = gnb.predict(x_test)
print(accuracy_score(y_test, g_pred))
print(confusion_matrix(y_test, g_pred))
# Out:
# 0.5842713605801919
# [[5703  833]
#  [4670 2031]]

# %%
sns.heatmap(confusion_matrix(y_test, g_pred), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
clf = SVC()
clf.fit(x_train, y_train)
s_pred = clf.predict(x_test)
print(accuracy_score(y_test, s_pred))
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, s_pred))
# Out:
# 0.7250887663367832
# [[5182 1354]
#  [2285 4416]]

# %%
sns.heatmap(confusion_matrix(y_test, s_pred), annot=True)
# Out:
# <Axes: >
